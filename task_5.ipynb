# %% [markdown]
# <a href="https://colab.research.google.com/github/suganyaudhaya/Data-science/blob/main/task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
a=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pollulation.zip')
print(a)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
a.mean()
# Out:
# <ipython-input-8-d6ac9701668a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.mean()
# Happiness Rank                   79.493671
# Happiness Score                   5.375734
# Standard Error                    0.047885
# Economy (GDP per Capita)          0.846137
# Family                            0.991046
# Health (Life Expectancy)          0.630259
# Freedom                           0.428615
# Trust (Government Corruption)     0.143422
# Generosity                        0.237296
# Dystopia Residual                 2.098977
# dtype: float64

# %%
a.mode()
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Afghanistan  Sub-Saharan Africa            82.0            5.192
# 1        Albania                 NaN             NaN              NaN
# 2        Algeria                 NaN             NaN              NaN
# 3         Angola                 NaN             NaN              NaN
# 4      Argentina                 NaN             NaN              NaN
# ..           ...                 ...             ...              ...
# 153    Venezuela                 NaN             NaN              NaN
# 154      Vietnam                 NaN             NaN              NaN
# 155        Yemen                 NaN             NaN              NaN
# 156       Zambia                 NaN             NaN              NaN
# 157     Zimbabwe                 NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03751                   0.00000  0.00000
# ...

# %%
a.std()
# Out:
# <ipython-input-12-7408fc62a40f>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.std()
# Happiness Rank                   45.754363
# Happiness Score                   1.145010
# Standard Error                    0.017146
# Economy (GDP per Capita)          0.403121
# Family                            0.272369
# Health (Life Expectancy)          0.247078
# Freedom                           0.150693
# Trust (Government Corruption)     0.120034
# Generosity                        0.126685
# Dystopia Residual                 0.553550
# dtype: float64

# %%
import array as np
np=(45,67)
print(np)
# Out:
# (45, 67)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
array=np.zeros(3)
print(array)
# Out:
# [0. 0. 0.]

# %%
import numpy as np
array=np.ones(3)
print(array)
# Out:
# [1. 1. 1.]

# %%
import numpy as np
import numpy as nd
import numpy as bb
import numpy as dd
np=np.array([5,3,8,9])
print(np)
nd=nd.arange(6)
print(nd)
bb=bb.linspace(0,5)
print(bb)
dd=dd.eye(3)
print(dd)
# Out:
# [5 3 8 9]
# [0 1 2 3 4 5]
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import numpy as np
k=np.array([[7,3,7],[6,3,0]])
g=k.shape
print(g)
h=k.ndim
print(h)
y=k.size
print(y)
f=k.dtype
print(f)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
import numpy as np
import pandas as pd
data={'FRIEND':['400 above','300_349','250-299','200-249','150-199','100-149','50-99','0-49'],
       'f':[2,5,12,17,23,49,27,29,36]}
df=pd.DataFrame(data)
